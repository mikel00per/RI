# %% [markdown]
# # Análisis Cinemático del Manipulador RR
# *Práctica 1. Robótica Industrial*

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

# %% [markdown]
# ## Cálculo del problema cinemático directo
# Con las herramientas tan simples que hemos utilizado en esta fase anterior, podemos ya realizar un análisis de problemas robóticos. Por ejemplo, podríamos dibujar 21 puntos de la trayectoria que recorre un efector de un **manipulador tipo RR** (por Rotación-Rotación, es decir, sus dos articulaciones son de rotación).
#
# <img src="data:image/png;base64,..." />
#
# Supongamos que sus enlaces tienen longitud $L_1 = L_2 = 1$, y las variables de rotación $\theta_1$ y $\theta_2$ varían uniformemente de 0 a $\pi/2$. Sabemos que las ecuaciones de la trayectoria son las siguientes:
# $$p_x = L_1\cos(\theta_1) + L_2\cos(\theta_1+\theta_2)$$
# $$p_y = L_1\sin(\theta_1) + L_2\sin(\theta_1+\theta_2)$$
#
# Podemos dibujar todos los puntos de la trayectoria mediante el código:

# %%
L1=1
L2=1
th1=np.arange(0, np.pi/2, np.pi/20)
th2=np.arange(0, np.pi/2, np.pi/20)
px=L1*np.cos(th1)+L2*np.cos(th1+th2)
py=L1*np.sin(th1)+L2*np.sin(th1+th2)
plt.plot(px,py)

# %% [markdown]
# ## Función para el Problema Cinemático Directo
# Cuando utilizamos algunas de las funciones varias veces, es conveniente definir funciones que realicen esa tarea, para conseguir una limpieza de código. En Jupyter, las funciones se definen de la misma forma que en Python convencional, es decir, utilizando el comando **def**. Para definir una función que calcule la trayectoria anterior podemos escribir:

# %%
def pcd(L1, L2, th1, th2):
    px=L1*np.cos(th1)+L2*np.cos(th1+th2)
    py=L1*np.sin(th1)+L2*np.sin(th1+th2)
    
    pcd = np.c_[px,py]
    return pcd

# %% [markdown]
# Al final, debemos juntar los vectores `px` y `py` en una matriz de tipo `np.array`, de forma que la primera columna `p[:,0]` contenga los valores $x$ y `p[:,1]` los valores de $y$. De este modo, el código anterior nos quedaría:

# %%
p = pcd(1,1,th1, th2)
fig, ax = plt.subplots()
ax.plot(p[:,0], p[:,1])

# %% [markdown]
# Es **importante** que veas que esta vez hemos utilizado ĺa función `plt.subplots()` para generar una figura (`fig`) y un objeto "ejes" dentro de la figura (`ax`), en lugar de usar directamente `plt.plot()`. Esto será muy útil más adelante, puesto que podremos especificar siempre el eje sobre el que queremos pintar.

# %% [markdown]
# ## Configuración espacial del robot
# Hasta ahora sólo hemos dibujado la trayectoria que sigue el efector del robot. Sin embargo, nos puede ser de utilidad ver la configuración del robot (variables de articulación) en cada momento de la trayectoria. Para ello, podemos crear una función que nos muestre el robot, dados los parámetros del robot $L_1$, $\theta_1$ y la posición del efector `p` (un vector que contiene `px` y `py` en ese instante). Esta función tendría una forma similar a:

# %%
def robot(L1,th1,p, ax):
    x=[0, L1*np.cos(th1), p[0]]
    y=[0, L1*np.sin(th1), p[1]]
    ax.plot(x,y, color='k', linewidth=2)
    ax.axis([-2, 2, -2, 2])
    ax.set_aspect('equal')

# %% [markdown]
# El código anterior muestra una línea que va desde el origen de coordenadas $(0,0)$ donde está situada la primera articulación $J_1$ hasta la segunda articulación del robot $J_2$, y luego hasta el punto final del mismo. Hemos aumentado el grosor de esta línea y cambiado el color a negro (k) para diferenciarlo bien de la trayectoria. Usaremos el objeto ejes (`ax`), que contiene las funciones `plot`, `axis` y `set_aspect`, para dibujar, establecer los límites y mantener la misma proporción en los ejes $x$ e $y$ todo el rato.
#
# **Ahora podemos probar a pintar el robot con una determinada configuración espacial, por ejemplo, $\theta_1=30^{\circ}$ y $\theta_2=60^{\circ}$. **

# %%
th1 = np.degrees(30)
th2 = np.degrees(60)
p = pcd(1,1, th1,th2)
fig, ax=plt.subplots()
robot(1,th1,p[-1],ax)

# %% [markdown]
# **Ejercicio (20 pts)**. Mezclar las dos imágenes anteriores, representando la trayectoria hasta un determinado punto y el brazo robótico en dicho punto. Completa el siguiente código para hacerlo. Recuerda que para pintar el robot solo tenemos que darle el último valor de `th1` y de `p`.

# %%
L1=1
L2=1
punto = 20
Npuntos = 50
th1=np.arange(0, punto*np.pi/(2*Npuntos), np.pi/Npuntos)
th2=np.arange(0, punto*np.pi/(2*Npuntos), np.pi/Npuntos)
p = pcd(L1,L2,th1,th2)
print (p)
# Out:
# [[2.         0.        ]
#  [1.99014143 0.18812375]
#  [1.96069786 0.37402312]
#  [1.91206374 0.55550587]
#  [1.84488984 0.73044356]
#  [1.76007351 0.89680225]
#  [1.65874511 1.05267166]
#  [1.54225104 1.19629253]
#  [1.41213348 1.3260816 ]
#  [1.27010722 1.44065385]]

# %%
fig,ax = plt.subplots() # creamos la figura y sus ejes
#Código del ejercicio
ax.plot(p[:,0], p[:,1])
robot(L1,th1[-1],p[-1,:],ax)

# %% [markdown]
# ## Trazado de la Trayectoria
# Para visualizar mejor la trayectoria, vamos a construir una animación. Para ello, importamos las herramientas necesarias.

# %%
from matplotlib import animation
from IPython.display import HTML

# %% [markdown]
# Para realizar la animación necesitamos crear los diferentes *frames* de la misma, y para ello necesitamos crear una figura y unos ejes (`fig`, `ax`) que habrá que limpiar en cada frame. Para ello, utilizaremos la función `init`:

# %%
def init():
    ax.clear() # Limpiamos los ejes actuales
    ax.set_xlabel('Eje X')
    ax.set_ylabel('Eje Y')
    ax.set_xlim(-2,2) # Establece los límites del eje x
    ax.set_ylim(-2,2) # y del eje y
    ax.set_aspect('equal') # Hace que la proporción de ambos ejes sea 1:1

# %% [markdown]
# Ahora tenemos que definir la función `pintarPCD` que es la que va a producir la animación, integrando las funciones `plot` y `robot`.

# %%
def pintarPCD(i, L1, L2, Npuntos,ax):
    init()
    # Resto de código para elegir el punto actual (i), 
    # pintar la trayectoria hasta el punto actual y
    # pintar el robot en esa configuración. 
    th1=np.arange(0, (i+1)*np.pi/(2*Npuntos), np.pi/Npuntos)
    th2=np.arange(0, (i+1)*np.pi/(2*Npuntos), np.pi/Npuntos)
    p = pcd(L1,L2,th1,th2)
    ax.plot(p[:,0], p[:,1])
    robot(L1,th1[-1],p[-1],ax)

# %% [markdown]
# Tras esto, crearemos la animación con el siguiente código. A la función `FuncAnimation` le pasaremos una serie de parámetros. El primero será `fig`, que será la figura donde se muestre toda la animación, y que ya hemos creado anteriormente. Después hemos puesto la función que realiza la animación, en nuestro caso se llama `pintarPCD` y ha sido definida en la anterior pieza de código. Después se le pasa el número de frames que se va a usar. Este número de frames es el parámetro `i` que recibe la función `pintarPCD`. El siguiente parámetro se llama `fargs`. que son los argumentos restantes que le pasamos a la función `pintarPCD`, en este caso (0, 1, `N`) son los valores para 'L1', 'L2', 'Npuntos' en la función `pintarPCD`. Y lo último que aparece es el parámetro `interval` que indica el intervalo entre frames en milisegundos.
#
# **Ejercicio (30 pts): Tras todas estas funciones, convertimos la animación `anim` en un video reproducible en HTML5, y lo reproducimos con el comando `HTML(anim.to_html5_video())`.**

# %%
fig, ax = plt.subplots()
anim = animation.FuncAnimation(fig, pintarPCD, frames = Npuntos, fargs = (1, 1, Npuntos, ax), interval = 30) 
HTML(anim.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imga305553cfb0746239cca00ff04eaedf6">
#     <br>
#     <input id="_anim_slidera305553cfb0746239cca00ff04eaedf6" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anima305553cfb0746239cca00ff04eaedf6.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anima305553cfb0746239cca00ff04eaedf6.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anima305553cfb0746239cca00ff04eaedf6.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anima305553cfb0746239cca00ff04eaedf6.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anima305553cfb0746239cca00ff04eaedf6.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anima305553cfb0746239cca00ff04eaedf6.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anima305553cfb0746239cca00ff04eaedf6.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anima305553cfb0746239cca00ff04eaedf6.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anima305553cfb0746239cca00ff04eaedf6.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anima305553cfb0746239cca00ff04eaedf6.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_selecta305553cfb0746239cca00ff04eaedf6" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imga305553cfb0746239cca00ff04eaedf6";
#     var slider_id = "_anim_slidera305553cfb0746239cca00ff04eaedf6";
#     var loop_select_id = "_anim_loop_selecta305553cfb0746239cca00ff04eaedf6";
#     var frames = new Array(0);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDIuMS4yLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvNQv5yAAAFipJREFUeJzt3X9sVfX9x/HXrVcIhB9ZtSy9Oc0c\
# uwwubeGmnI6SuQYspVqyyxSnJWTA+HGHYjRzGyPLYsI2ZnXDyVJidp0TbDK64GBtCG0AlSwhYHP5\
# MeIq28VRbS8FWicLTBQs5/vHt99+Kb0VlMs593N5PpImnHs+nr5vzM2Tczg99TmO4wgAAMPkeD0A\
# AACfBwEDABiJgAEAjETAAABGImAAACMRMACAkQgYAMBIBAwAYCQCBgAwEgEDABiJgAEAjETAAABG\
# ImAAACMRMACAkQgYAMBIBAwAYCQCBgAwEgEDABiJgAEAjETAAABGImAAACMRMACAkQgYAMBIBAwA\
# YCQCBgAwEgEDABiJgAEAjETAAABGImAAACMRMACAkQiYizo6OjRr1iyFQiEVFhZqw4YNg9Y4jqPH\
# H39cwWBQU6ZM0aFDhzyYFAAyn9/rAW4lfr9f69evV0lJic6dO6dp06apsrJSkydP7l/T3NysRCKh\
# RCKhN998U4888ojefPNND6cGgMzEGZiL8vPzVVJSIkkaPXq0QqGQksnkgDWNjY1atGiRfD6fysrK\
# dPbsWXV1dXkxLgBkNALmkfb2dh0+fFjTp08f8HoymVRBQUH/tmVZgyIHAOASoifOnz+v+fPn6/nn\
# n9eYMWMG7HMcZ9B6n8836LVYLKZYLCZJOnbsmCZNmnRzhgWg9vZ29fT0eD0GrkLAXHbp0iXNnz9f\
# Cxcu1AMPPDBov2VZ6ujo6N/u7OxUIBAYtC4ajSoajUqSbNtWPB6/eUMDtzjbtr0eASlwCdFFjuNo\
# 2bJlCoVCevLJJ1OuiUQieuWVV+Q4jg4cOKCxY8cqPz/f5UkBIPNxBuaiffv2qb6+XsXFxQqHw5Kk\
# X/7yl3rvvfckSStXrlR1dbV27typYDCokSNH6uWXX/ZyZADIWATMRXfffXfKf+O6ks/n08aNG12a\
# CADMxSVEAICRCBgAwEgEDABgJAIGADASAQMAGImAAQCMRMAAAEYiYAAAIxEwAICRCBgAwEgEDABg\
# JAIGADASAQMAGImAAQCMRMAAAEYiYAAAIxEwAICRCBgAwEgEzEVLly7VuHHjVFRUlHL/3r17NXbs\
# WIXDYYXDYf3sZz9zeUIAMIff6wFuJUuWLNFjjz2mRYsWDbnmG9/4hnbs2OHiVABgJs7AXFReXq7c\
# 3FyvxwCArEDAMsz+/fs1depU3Xffffr73//u9TgAkLG4hJhBSkpK9O6772rUqFHauXOnvvWtbymR\
# SKRcG4vFFIvFJEnd3d1ujgkAGYEzsAwyZswYjRo1SpJUXV2tS5cuqaenJ+XaaDSqeDyueDyuvLw8\
# N8cEgIxAwDLIqVOn5DiOJKm1tVWXL1/WHXfc4fFUAJCZuIToogULFmjv3r3q6emRZVlau3atLl26\
# JElauXKlXn31Vb3wwgvy+/0aMWKEGhoa5PP5PJ4aADKTz/m/v/LDWLZtKx6Pez0GkLX4jGUmLiEC\
# AIxEwAAARiJgAAAjETAAgJEIGADASAQMAGAkAgYAMBIBAwAYiYABAIxEwAAARiJgAAAjETAAgJEI\
# GADASAQMAGAkAgYAMBIBAwAYiYABAIxEwAAARiJgLlq6dKnGjRunoqKilPsdx9Hjjz+uYDCoKVOm\
# 6NChQy5PCADmIGAuWrJkiVpaWobc39zcrEQioUQioVgspkceecTF6QDALATMReXl5crNzR1yf2Nj\
# oxYtWiSfz6eysjKdPXtWXV1dLk4IAOYgYBkkmUyqoKCgf9uyLCWTSQ8nAoDM5fd6APw/x3EGvebz\
# +VKujcViisVikqTu7u6bOhcAZCLOwDKIZVnq6Ojo3+7s7FQgEEi5NhqNKh6PKx6PK

# %% [markdown]
# ## Problema Cinemático Inverso
# Quizá te habrás preguntado (seguro que sí) si conocer de antemano las variables de articulación es lo normal. Por supuesto que no. Normalmente, el problema es precisamente conocer las variables de articulación a partir del punto donde queremos que esté el actuador del robot. Esto es lo que se conoce como **Problema Cinemático Inverso** (PCI). Las ecuaciones del PCI para el robot RR son:
#
# $$ \cos\theta_2 = \frac{x^2+y^2-L_1^2 -L_2^2}{2L_1 L_2}$$
#
# $$ \tan\theta_1 = \frac{y(L_1 + L_2\cos\theta_2)-xL_2\sin\theta_2}{x(L_1 + L_2\cos\theta_2)+yL_2\sin\theta_2}$$
#
# Ahora vamos a representar trayectorias. Para ello utilizaremos una aproximación de trayectoria rectilínea. De esta forma, los puntos por los que pasa el actuador se pueden parametrizar como:
#
# $$ x_n = x_{ini} + \frac{x_{fin}-x_{ini}}{N}n$$
#
# $$ y_n = y_{ini} + \frac{y_{fin}-y_{ini}}{N}n$$
#
# donde $n=0,1\dots N$ y $n$ representa el numero de punto en una trayectoria de `N+1` puntos.
#
# **Ahora vamos a escribir un programa que simule el movimiento del robot y dibuje la trayectoria (similar al realizado en el apartado anterior) para un movimiento rectilíneo entre dos puntos cualesquiera. Para ello, se utilizara la función `robot` de los apartados anteriores y se construira una nueva función `pci` que implemente las ecuaciones del PCI.  Debe tenerse en cuenta que las funciones `np.arccos` y `np.arctan` de NumPy toman valores en los intervalos $(0, \pi)$ y $(-\pi/2,\pi/2)$ respectivamente**.

# %%
def pci(L1,L2,x,y):
    # Devuelve un array con los valores de th1 y th2 para las posiciones (x,y). 
    th1 = np.arccos((x*x+y*y-L1*L1-L2*L2)/(2*L1*L2))
    th2 = np.arctan((y*(L1+L2*np.cos(th1))-(x*L2*np.sin(th1)))/((x*(L1+L2*np.cos(th1))+(y*L2*np.sin(th1)))))
    vector = np.c_[th1,th2]
    return vector

# %%
def pintarPCI1(i, L1, L2, pini, pfin, Npuntos,ax):
    # Pinta la trayectoria actual y la posición actual del robot 
    # calculada con pci. Podemos acceder a p (variable global) 
    # desde dentro de la función. 
    init()
    x_a = pini[:,0] + ((pfin[:,0] - pini[:,0])/Npuntos) * i
    y_a = pini[:,1] + ((pfin[:,1] - pini[:,1])/Npuntos) * i
    
    pp = np.c_[x_a,y_a]
    thn = pci(L1,L2,x_a,y_a)
    ax.plot(pp[:,0], pp[:,1])
    robot(L1,thn[:,1],pp[-1],ax)

# %% [markdown]
# Probaremos las siguientes trayectorias:
#
# - **Trayectoria 1 (10 pts)**: $(x_{ini}, y_{ini})=(2,0)$ y $(x_{fin}, y_{fin})=(0,2)$

# %%
# Genera la trayectoria y su correspondiente animación, y la muestra con HTML(anim.to_html5_video())
fig, ax = plt.subplots()
anim = animation.FuncAnimation(fig, pintarPCI1, frames = Npuntos, fargs = (1, 1, np.c_[2,0], np.c_[0,2], Npuntos, ax), interval = 30)
HTML(anim.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgcb617da41eda47019bf878d155758cce">
#     <br>
#     <input id="_anim_slidercb617da41eda47019bf878d155758cce" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="animcb617da41eda47019bf878d155758cce.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animcb617da41eda47019bf878d155758cce.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="animcb617da41eda47019bf878d155758cce.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="animcb617da41eda47019bf878d155758cce.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="animcb617da41eda47019bf878d155758cce.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="animcb617da41eda47019bf878d155758cce.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="animcb617da41eda47019bf878d155758cce.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="animcb617da41eda47019bf878d155758cce.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="animcb617da41eda47019bf878d155758cce.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="animcb617da41eda47019bf878d155758cce.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_selectcb617da41eda47019bf878d155758cce" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgcb617da41eda47019bf878d155758cce";
#     var slider_id = "_anim_slidercb617da41eda47019bf878d155758cce";
#     var loop_select_id = "_anim_loop_selectcb617da41eda47019bf878d155758cce";
#     var frames = new Array(0);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDIuMS4yLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvNQv5yAAAFipJREFUeJzt3X9sVfX9x/HXrVcIhB9ZtSy9Oc0c\
# uwwubeGmnI6SuQYspVqyyxSnJWTA+HGHYjRzGyPLYsI2ZnXDyVJidp0TbDK64GBtCG0AlSwhYHP5\
# MeIq28VRbS8FWicLTBQs5/vHt99+Kb0VlMs593N5PpImnHs+nr5vzM2Tczg99TmO4wgAAMPkeD0A\
# AACfBwEDABiJgAEAjETAAABGImAAACMRMACAkQgYAMBIBAwAYCQCBgAwEgEDABiJgAEAjETAAABG\
# ImAAACMRMACAkQgYAMBIBAwAYCQCBgAwEgEDABiJgAEAjETAAABGImAAACMRMACAkQgYAMBIBAwA\
# YCQCBgAwEgEDABiJgAEAjETAAABGImAAACMRMACAkQiYizo6OjRr1iyFQiEVFhZqw4YNg9Y4jqPH\
# H39cwWBQU6ZM0aFDhzyYFAAyn9/rAW4lfr9f69evV0lJic6dO6dp06apsrJSkydP7l/T3NysRCKh\
# RCKhN998U4888ojefPNND6cGgMzEGZiL8vPzVVJSIkkaPXq0QqGQksnkgDWNjY1atGiRfD6fysrK\
# dPbsWXV1dXkxLgBkNALmkfb2dh0+fFjTp08f8HoymVRBQUH/tmVZgyIHAOASoifOnz+v+fPn6/nn\
# n9eYMWMG7HMcZ9B6n8836LVYLKZYLCZJOnbsmCZNmnRzhgWg9vZ29fT0eD0GrkLAXHbp0iXNnz9f\
# Cxcu1AMPPDBov2VZ6ujo6N/u7OxUIBAYtC4ajSoajUqSbNtWPB6/eUMDtzjbtr0eASlwCdFFjuNo\
# 2bJlCoVCevLJJ1OuiUQieuWVV+Q4jg4cOKCxY8cqPz/f5UkBIPNxBuaiffv2qb6+XsXFxQqHw5Kk\
# X/7yl3rvvfckSStXrlR1dbV27typYDCokSNH6uWXX/ZyZADIWATMRXfffXfKf+O6ks/n08aNG12a\
# CADMxSVEAICRCBgAwEgEDABgJAIGADASAQMAGImAAQCMRMAAAEYiYAAAIxEwAICRCBgAwEgEDABg\
# JAIGADASAQMAGImAAQCMRMAAAEYiYAAAIxEwAICRCBgAwEgEzEVLly7VuHHjVFRUlHL/3r17NXbs\
# WIXDYYXDYf3sZz9zeUIAMIff6wFuJUuWLNFjjz2mRYsWDbnmG9/4hnbs2OHiVABgJs7AXFReXq7c\
# 3FyvxwCArEDAMsz+/fs1depU3Xffffr73//u9TgAkLG4hJhBSkpK9O6772rUqFHauXOnvvWtbymR\
# SKRcG4vFFIvFJEnd3d1ujgkAGYEzsAwyZswYjRo1SpJUXV2tS5cuqaenJ+XaaDSqeDyueDyuvLw8\
# N8cEgIxAwDLIqVOn5DiOJKm1tVWXL1/WHXfc4fFUAJCZuIToogULFmjv3r3q6emRZVlau3atLl26\
# JElauXKlXn31Vb3wwgvy+/0aMWKEGhoa5PP5PJ4aADKTz/m/v/LDWLZtKx6Pez0GkLX4jGUmLiEC\
# AIxEwAAARiJgAAAjETAAgJEIGADASAQMAGAkAgYAMBIBAwAYiYABAIxEwAAARiJgAAAjETAAgJEI\
# GADASAQMAGAkAgYAMBIBAwAYiYABAIxEwAAARiJgLlq6dKnGjRunoqKilPsdx9Hjjz+uYDCoKVOm\
# 6NChQy5PCADmIGAuWrJkiVpaWobc39zcrEQioUQioVgspkceecTF6QDALATMReXl5crNzR1yf2Nj\
# oxYtWiSfz6eysjKdPXtWXV1dLk4IAOYgYBkkmUyqoKCgf9uyLCWTSQ8nAoDM5fd6APw/x3EGvebz\
# +VKujcViisVikqTu7u6bOhcAZCLOwDKIZVnq6Ojo3+7s7FQgEEi5NhqNKh6PKx6PK

# %% [markdown]
# - **Trayectoria 2 (20 pts)**: $(x_{ini}, y_{ini})=(1,1)$ y $(x_{fin}, y_{fin})=(-1,0)$.

# %%
# Prueba a utilizar el mismo código anterior 
# con estos nuevos valores x_ini, y_ini, x_fin, y_fin
fig, ax = plt.subplots()
anim = animation.FuncAnimation(fig, pintarPCI1, frames = Npuntos, fargs = (1, 1, np.c_[1,1],np.c_[-1,0], Npuntos, ax), interval = 30)
HTML(anim.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_
# GImAAQCMRMAAAEYiYAAAIxEwAICRCBgAwEgEDABgJAIGADASAXPR0qVLlZ+fr+Li4pT79+7dq7Fj\
# xyocDiscDutnP/uZyxMCgDn8Xg9wK1myZIkee+wxLVq0aMg13/jGN7Rz504XpwIAM3EG5qLy8nLl\
# 5uZ6PQYAZAUClmH27dunKVOm6L777tPf//53r8cBgIzFJcQMUlpaqnfffVejRo3Srl279K1vfUuJ\
# RCLl2lgsplgsJknq7u52c0wAyAicgWWQMWPGaNSoUZKk6upqXbp0ST09PSnXRqNRxeNxxeNx5eXl\
# uTkmAGQEApZBTp06JcdxJEltbW26fPmy7rjjDo+nAoDMxCVEFy1YsEB79+5VT0+PLMvS2rVrdenS\
# JUnSypUr9eqrr+qFF16Q3+/XiBEjVF9fL5/P5/HUAJCZfM7//soPY9m2rXg87vUYQNbiM5aZuIQI\
# ADASAQMAGImAAQCMRMAAAEYiYAAAIxEwAICRCBgAwEgEDABgJAIGADASAQMAGImAAQCMRMAAAEYi\
# YAAAIxEwAICRCBgAwEgEDABgJAIGADASAQMAGImAuWjp0qXKz89XcXFxyv2O4+jxxx9XMBjU5MmT\
# dfDgQZcnBABzEDAXLVmyRM3NzUPub2pqUiKRUCKRUCwW0yOPPOLidABgFgLmovLycuXm5g65v6Gh\
# QYsWLZLP51NZWZnOnj2rkydPujghAJiDgGWQZDKpwsLC/m3LspRMJj2cCLh+Pp9PPp/P6zFwC/F7\
# PQD+P8dxBr021P8QYrGYYrGYJKm7u/umzgUAmYgzsAxiWZY6Ozv7t7u6uhQIBFKuj

# %% [markdown]
# Verás que no funciona correctamente. Esto sucede porque la función `arctan` no determina correctamente el cuadrante de la solución. Esto causa problemas de continuidad, por lo que debemos utilizar la función `arctan2` para sustituir a la anterior. Utiliza la ayuda para conocer los parámetros de esta función, y reescribe la función `pci` y `pintarPCI` para poder utilizarlas.

# %%
# Define aquí tu nueva función pci2 y pintarPCI2:
def pci2(L1,L2,x,y):
    # Devuelve un array con los valores de th1 y th2 para las posiciones (x,y). 
    th1 = np.arccos((x*x+y*y-L1*L1-L2*L2)/(2*L1*L2))
    th2 = np.arctan2(
        (y*(L1+L2*np.cos(th1))-(x*L2*np.sin(th1))),
        ((x*(L1+L2*np.cos(th1))+(y*L2*np.sin(th1)))) 
    )
    vector = np.c_[th1,th2]
    return vector

def pintarPCI2(i, L1, L2, pini, pfin, Npuntos, ax):
    # Igual que pintarPCI1 pero llamando a pci2. 
    init()
    x_a = pini[:,0] + ((pfin[:,0] - pini[:,0])/Npuntos) * i
    y_a = pini[:,1] + ((pfin[:,1] - pini[:,1])/Npuntos) * i
    pp = np.c_[x_a,y_a]
    
    thn = pci2(L1,L2,x_a,y_a)
    ax.plot(pp[:,0], pp[:,1])
    robot(L1,thn[:,1],pp[-1],ax)

# %%
# Calcula la trayectoria y pintala de nuevo, con los nuevos pci2 y pintarPCI2. 
fig, ax = plt.subplots()
anim = animation.FuncAnimation(fig, pintarPCI2, frames = Npuntos, fargs = (1, 1, np.c_[1,1], np.c_[-1,0], Npuntos, ax), interval = 30)
HTML(anim.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgbea52316e7e04b3ea7a6ff5d4d1058a7">
#     <br>
#     <input id="_anim_sliderbea52316e7e04b3ea7a6ff5d4d1058a7" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="
# Como ves, volvemos a tener problemas de continuidad. Esto es porque la función $\arccos$ devuelve dos resultados: el ángulo positivo que nos devuelve `arccos()`, y el mismo pero con signo negativo. Para escoger una solución u otra, puede tomarse el siguiente criterio: dado que $\theta_1$ se obtiene a partir de $\theta_2$, es lógico seleccionar la solución de $\arccos(\theta_2)$ que hace que el incremento en $\theta_1$ desde el punto anterior de la trayectoria al actual sea el menor posible.

# %%
# Define aquí tu nueva función pci3 y pintarPCI3
def pci3(L1,L2,x,y):
    # Devuelve un array con los valores de th1 y th2 para las posiciones (x,y). 
    th2 = np.arccos((x*x+y*y-L1*L1-L2*L2)/(2*L1*L2))
    th2_2 = -th2
    th1 = np.arctan2(
        (y*(L1+L2*np.cos(th2))-(x*L2*np.sin(th2))),
        ((x*(L1+L2*np.cos(th2))+(y*L2*np.sin(th2)))) 
    )
    th1_2 = np.arctan2(
        (y*(L1+L2*np.cos(th2_2))-(x*L2*np.sin(th2_2))),
        ((x*(L1+L2*np.cos(th2_2))+(y*L2*np.sin(th2_2)))) 
    )
    
    if th1 >=0 :   vector = np.c_[th1,th2]
    else:          vector = np.c_[th1_2,th2_2]
    

    return vector

def pintarPCI3(i, L1, L2, pini, pfin, Npuntos, ax):
    # Igual que pintarPCI1 pero llamando a pci2. 
    init()
    x_a = pini[:,0] + ((pfin[:,0] - pini[:,0])/Npuntos) * i
    y_a = pini[:,1] + ((pfin[:,1] - pini[:,1])/Npuntos) * i
    pp = np.c_[x_a,y_a]
    
    thn = pci3(L1,L2,x_a,y_a)
    ax.plot(pp[:,0], pp[:,1])
    robot(L1,thn[:,1],pp[-1],ax)

# %%
# Calcula la trayectoria y pintala de nuevo, con los nuevos pci3 y pintarPCI3. 
fig, ax = plt.subplots()
anim = animation.FuncAnimation(fig, pintarPCI3, frames = Npuntos, fargs = (1, 1, np.c_[1,0],np.c_[-1,0], Npuntos, ax), interval = 30)
HTML(anim.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img3aec97c49ee74ec3bd7ef9657da2875d">
#     <br>
#     <input id="_anim_slider3aec97c49ee74ec3bd7ef9657da2875d" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anim3aec97c49ee74ec3bd7ef9657da2875d.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim3aec97c49ee74ec3bd7ef9657da2875d.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anim3aec97c49ee74ec3bd7ef9657da2875d.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anim3aec97c49ee74ec3bd7ef9657da2875d.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anim3aec97c49ee74ec3bd7ef9657da2875d.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anim3aec97c49ee74ec3bd7ef9657da2875d.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anim3aec97c49ee74ec3bd7ef9657da2875d.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anim3aec97c49ee74ec3bd7ef9657da2875d.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anim3aec97c49ee74ec3bd7ef9657da2875d.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anim3aec97c49ee74ec3bd7ef9657da2875d.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_select3aec97c49ee74ec3bd7ef9657da2875d" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img3aec97c49ee74ec3bd7ef9657da2875d";
#     var slider_id = "_anim_slider3aec97c49ee74ec3bd7ef9657da2875d";
#     var loop_select_id = "_anim_loop_select3aec97c49ee74ec3bd7ef9657da2875d";
#     var frames = new Array(0);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDIuMS4yLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvNQv5yAAAHyNJREFUeJzt3XtYVHXix/HPKGmalw3DDRp3XcMQ\
# AWVlNMzi8YamblhppeuzapZkaaKYlzS7qHi/QOG6TVmaPWqPlmEm1HprW0Np8pqkoUkCaoJpPzUV\
# hPP7Y102BVNzmDMH3q9/4sz5cs5nnpo+fM+c+Y7NMAxDAABYTDWzAwAA8FtQYAAAS6LAAACWRIEB\
